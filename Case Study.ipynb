# %%
# Pandas, numpy, matplotlib ve seaborn kütüphanelerini yükleyelim
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Reading the data
tdm = pd.read_csv("term-deposit-marketing-2020.csv")
print(tdm.head())

# Checking column names of the data
print("\nColumn names:", tdm.columns)

# Number of rows and columns
print("\nNumber of rows and columns:",tdm.shape)
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign   y
# 0  unknown    5   may       261         1  no
# 1  unknown    5   may       151         1  no
# 2  unknown    5   may        76         1  no
# 3  unknown    5   may        92         1  no
# 4  unknown    5   may       198         1  no
#
# Column names: Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'y'],
#       dtype='object')
#
# Number of rows and columns: (40000, 14)

# %%
#Checking whether there is a null value or not
tdm.isnull().sum()
#There is no nully value in the data
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# y            0
# dtype: int64

# %%
# Checking NAs.
tdm.isna().any()
#There is no 'not a number' value in the data
# Out:
# age          False
# job          False
# marital      False
# education    False
# default      False
# balance      False
# housing      False
# loan         False
# contact      False
# day          False
# month        False
# duration     False
# campaign     False
# y            False
# dtype: bool

# %%
#Checking structure of the data
print(tdm.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        40000 non-null  int64
#  1   job        40000 non-null  object
#  2   marital    40000 non-null  object
#  3   education  40000 non-null  object
#  4   default    40000 non-null  object
#  5   balance    40000 non-null  int64
#  6   housing    40000 non-null  object
#  7   loan       40000 non-null  object
#  8   contact    40000 non-null  object
#  9   day        40000 non-null  int64
#  10  month      40000 non-null  object
#  11  duration   40000 non-null  int64
#  12  campaign   40000 non-null  int64
#  13  y          40000 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 4.3+ MB
# None

# %%
#Creating a summary table which includes min, max ,mean, median and standard deviation of the numeric variables
tdm.pivot_table(values=('age', 'balance', 'day', 'duration', 'campaign'
                         ), index="y", aggfunc=[min, max, np.mean, 'median', np.std], margins=True)
# Out:
#     min                               max                                ...  \
#     age balance campaign day duration age balance campaign day duration  ...
# y                                                                        ...
# no   19   -8019        1   1        0  94  102127       63  31     4918  ...
# yes  19   -3058        1   1        8  95   45248       32  31     3881  ...
# All  19   -8019        1   1        0  95  102127       63  31     4918  ...
#
#            std                                                      var  \
#            age      balance  campaign       day    duration         age
# y
# no    9.525450  2900.722436  3.298031  8.255850  206.360022   90.734194
# yes  11.001984  2924.894429  2.306015  8.557604  431.287174  121.043657
# All   9.641655  2903.733418  3.239011  8.278024  259.363256   92.961511
#
#
#           balance   campaign        day       duration
# y
# no   8.414191e+06  10.877009  68.159066   42584.458783
# yes  8.555007e+06   5.317707  73.232583  186008.626262
# All  8.431668e+06  10.491192  68.525678   67269.298580
#
# [3 rows x 30 columns]

# %%
#Distribution of job types over y ( has the client subscribed to a term deposit)
plt.figure(dpi=50)
with sns.axes_style("white"):
    g = sns.catplot(x="y", data=tdm, kind="count", hue="job",palette="magma",aspect=2, height=5)
    g.set_xticklabels(step=1,fontsize=13, rotation=90)
    g.set_yticklabels(fontsize=13)
    g.ax.set(ylim=(0, 4500))

# %%
plt.figure(dpi=5)
with sns.axes_style("white"):
    g = sns.catplot(x="y", data=tdm, kind="count", hue="marital",palette="mako",aspect=2, height=5)
    g.set_xticklabels(step=1,fontsize=13, rotation=90)
    g.set_yticklabels(fontsize=13)
    g.ax.set(ylim=(0, 15000))

# %%
plt.figure(dpi=10)
with sns.axes_style("white"):
    g = sns.catplot(x="y", data=tdm, kind="count", hue="education",palette="Spectral",aspect=2, height=5)
    g.set_xticklabels(step=1,fontsize=13, rotation=90)
    g.set_yticklabels(fontsize=13)
    g.ax.set(ylim=(0, 15000))

# %%
plt.figure(dpi=15)
with sns.axes_style("white"):
    g = sns.catplot(x="y", data=tdm, kind="count", hue="housing",palette="magma",aspect=2, height=5)
    g.set_xticklabels(step=1,fontsize=13, rotation=90)
    g.set_yticklabels(fontsize=13)
    g.ax.set(ylim=(0, 20000))

# %%
plt.figure(dpi=10)
with sns.axes_style("white"):
    g = sns.catplot(x="y", data=tdm, kind="count", hue="loan",palette="mako",aspect=2, height=5)
    g.set_xticklabels(step=1,fontsize=13, rotation=90)
    g.set_yticklabels(fontsize=13)
    g.ax.set(ylim=(0, 15000))

# %%
plt.figure(dpi=10)
with sns.axes_style("white"):
    g = sns.catplot(x="y", data=tdm, kind="count", hue="contact",palette="Spectral",aspect=2, height=5)
    g.set_xticklabels(step=1,fontsize=13, rotation=90)
    g.set_yticklabels(fontsize=13)
    g.ax.set(ylim=(0, 10000))

# %%
#Frequencies of the categorical variable
print(pd.crosstab(index=tdm['job'], columns='job'),"\n ","\n ",
pd.crosstab(index=tdm['marital'], columns='marital'),"\n ","\n ",
pd.crosstab(index=tdm['education'], columns='education'),"\n ","\n ",
pd.crosstab(index=tdm['contact'], columns='contact'))
# Out:
# col_0           job
# job
# admin          4483
# blue-collar    9383
# entrepreneur   1405
# housemaid      1087
# management     8166
# retired        1437
# self-employed  1414
# services       3910
# student         524
# technician     6852
# unemployed     1104
# unknown         235
#
#   col_0     marital
# marital
# divorced     4725
# married     24386
# single      10889
#
#   col_0      education
# education
# primary         6270
# secondary      20993
# tertiary       11206
# unknown         1531
#
#   col_0      contact
# contact
# cellular     24914
# telephone     2321
# unknown      12765

# %%
#Frequencies of the binary variables
print(pd.crosstab(index=tdm['housing'], columns='month')
      pd.crosstab(index=tdm['loan'], columns='month'),"\n ","\n ",
      pd.crosstab(index=tdm['default'], columns='default'))
# Out:
# col_0    month
# housing
# no       15969
# yes      24031
#
#   col_0  month
# loan
# no     33070
# yes     6930
#
#   col_0    default
# default
# no         39191
# yes          809

# %%
#Arranging binary variables as numeric
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
default_encoded = le.fit_transform(tdm['default'])
housing_encoded = le.fit_transform(tdm['housing'])
loan_encoded = le.fit_transform(tdm['loan'])

y_encoded = le.fit_transform(tdm['y'])


tdm['default'] = default_encoded
tdm['housing'] = housing_encoded
tdm['loan'] = loan_encoded
tdm['y'] = y_encoded

tdm.head()
# Out:
#    age           job  marital  education  default  balance  housing  loan  \
# 0   58    management  married   tertiary        0     2143        1     0
# 1   44    technician   single  secondary        0       29        1     0
# 2   33  entrepreneur  married  secondary        0        2        1     1
# 3   47   blue-collar  married    unknown        0     1506        1     0
# 4   33       unknown   single    unknown        0        1        0     0
#
#    contact  day month  duration  campaign  y
# 0  unknown    5   may       261         1  0
# 1  unknown    5   may       151         1  0
# 2  unknown    5   may        76         1  0
# 3  unknown    5   may        92         1  0
# 4  unknown    5   may       198         1  0

# %%
#Checking levels of categorical variables 
print(tdm.job.unique())
print(tdm.marital.unique())
print(tdm.education.unique())
print(tdm.contact.unique())
print(tdm.month.unique())
# Out:
# ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
# ['married' 'single' 'divorced']
# ['tertiary' 'secondary' 'unknown' 'primary']
# ['unknown' 'cellular' 'telephone']
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr']

# %%
#Turning categorical variables as dummy variables with one hot encodeding 
new_data = pd.get_dummies(tdm, columns = ['job', 'marital','education','contact','month'])
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 42 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  40000 non-null  int64
#  1   default              40000 non-null  int32
#  2   balance              40000 non-null  int64
#  3   housing              40000 non-null  int32
#  4   loan                 40000 non-null  int32
#  5   day                  40000 non-null  int64
#  6   duration             40000 non-null  int64
#  7   campaign             40000 non-null  int64
#  8   y                    40000 non-null  int32
#  9   job_admin            40000 non-null  uint8
#  10  job_blue-collar      40000 non-null  uint8
#  11  job_entrepreneur     40000 non-null  uint8
#  12  job_housemaid        40000 non-null  uint8
#  13  job_management       40000 non-null  uint8
#  14  job_retired          40000 non-null  uint8
#  15  job_self-employed    40000 non-null  uint8
#  16  job_services         40000 non-null  uint8
#  17  job_student          40000 non-null  uint8
#  18  job_technician       40000 non-null  uint8
#  19  job_unemployed       40000 non-null  uint8
#  20  job_unknown          40000 non-null  uint8
#  21  marital_divorced     40000 non-null  uint8
#  22  marital_married      40000 non-null  uint8
#  23  marital_single       40000 non-null  uint8
#  24  education_primary    40000 non-null  uint8
#  25  education_secondary  40000 non-null  uint8
#  26  education_tertiary   40000 non-null  uint8
#  27  education_unknown    40000 non-null  uint8
#  28  contact_cellular     40000 non-null  uint8
#  29  contact_telephone    40000 non-null  uint8
#  30  contact_unknown      40000 non-null  uint8
#  31  month_apr            40000 non-null  uint8
#  32  month_aug            40000 non-null  uint8
#  33  month_dec            40000 non-null  uint8
#  34  month_feb            40000 non-null  uint8
#  35  month_jan            40000 non-null  uint8
#  36  month_jul            40000 non-null  uint8
#  37  month_jun            40000 non-null  uint8
#  38  month_mar            40000 non-null  uint8
#  39  month_may            40000 non-null  uint8
#  40  month_nov            40000 non-null  uint8
#  41  month_oct            40000 non-null  uint8
# dtypes: int32(4), int64(5), uint8(33)
# memory usage: 3.4 MB

# %%
#Checking correlation of the variables 
corr=new_data.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_e0734_row0_col0,#T_e0734_row1_col1,#T_e0734_row2_col2,#T_e0734_row3_col3,#T_e0734_row4_col4,#T_e0734_row5_col5,#T_e0734_row6_col6,#T_e0734_row7_col7,#T_e0734_row8_col8,#T_e0734_row9_col9,#T_e0734_row10_col10,#T_e0734_row11_col11,#T_e0734_row12_col12,#T_e0734_row13_col13,#T_e0734_row14_col14,#T_e0734_row15_col15,#T_e0734_row16_col16,#T_e0734_row17_col17,#T_e0734_row18_col18,#T_e0734_row19_col19,#T_e0734_row20_col20,#T_e0734_row21_col21,#T_e0734_row22_col22,#T_e0734_row23_col23,#T_e0734_row24_col24,#T_e0734_row25_col25,#T_e0734_row26_col26,#T_e0734_row27_col27,#T_e0734_row28_col28,#T_e0734_row29_col29,#T_e0734_row30_col30,#T_e0734_row31_col31,#T_e0734_row32_col32,#T_e0734_row33_col33,#T_e0734_row34_col34,#T_e0734_row35_col35,#T_e0734_row36_col36,#T_e0734_row37_col37,#T_e0734_row38_col38,#T_e0734_row39_col39,#T_e0734_row40_col40,#T_e0734_row41_col41{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T
col11,#T_e0734_row28_col38,#T_e0734_row29_col2,#T_e0734_row29_col15,#T_e0734_row29_col19,#T_e0734_row32_col17,#T_e0734_row33_col14,#T_e0734_row34_col15,#T_e0734_row35_col14,#T_e0734_row35_col15,#T_e0734_row36_col1,#T_e0734_row38_col35,#T_e0734_row40_col19,#T_e0734_row40_col39,#T_e0734_row41_col2,#T_e0734_row41_col11,#T_e0734_row41_col14,#T_e0734_row41_col15,#T_e0734_row41_col35{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_e0734_row0_col8,#T_e0734_row1_col20,#T_e0734_row5_col20,#T_e0734_row6_col20,#T_e0734_row6_col41,#T_e0734_row9_col41,#T_e0734_row11_col15,#T_e0734_row12_col1,#T_e0734_row13_col1,#T_e0734_row15_col4,#T_e0734_row16_col1,#T_e0734_row17_col20,#T_e0734_row18_col2,#T_e0734_row23_col20,#T_e0734_row24_col1,#T_e0734_row24_col4,#T_e0734_row24_col15,#T_e0734_row24_col18,#T_e0734_row25_col8,#T_e0734_row26_col41,#T_e0734_row27_col1,#T_e0734_row28_col1,#T_e0734_row33_col1,#T_e0734_row34_col4,#T_e0734_row36_col31,#T_e0734_row39_col15{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_e0734_row0_col10,#T_e0734_row6_col32,#T_e0734_row17_col27,#T_e0734_row17_col32,#T_e0734_row21_col29,#T_e0734_row22_col39,#T_e0734_row23_col32,#T_e0734_row26_col36,#T_e0734_row30_col13,#T_e0734_row38_col34{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_e0734_row0_col11,#T_e0734_row1_col11,#T_e0734_row6_col35,#T_e0734_row12_col17,#T_e0734_row19_col17,#T_e0734_row27_col35,#T_e0734_row29_col12,#T_e0734_row31_col6,#T_e0734_row32_col12,#T_e0734_row32_col14,#T_e0734_row34_col40,#T_e0734_row36_col11,#T_e0734_row39_col37{
#             background-color:  #ede8f3;
#             color:  #000000;
#         }#T_e0734_row0_col12,#T_e0734_row3_col0,

# %%
#Pairplot of the data
#Checking the distribution of the variable
sns.pairplot(data=tdm, height=2.5,kind="reg", hue="y")

# %% [markdown]
# # Modelling

# %%
#Preparing the data for modelling
X = new_data.drop(columns=["y"]).values 
y= new_data["y"].values
Y= new_data["y"].values

# %% [markdown]
# ### 1. Logistic Regression

# %%
# evaluate a logistic regression model using k-fold cross-validation
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# prepare the cross-validation procedure
cv = KFold(n_splits=5, random_state=1, shuffle=True)
# create model
model = LogisticRegression()
# evaluate model
scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# report performance
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
logistic=mean(scores)
# Out:
# Accuracy: 0.933 (0.002)

# %% [markdown]
# ### 2. Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# Construct model
dt = DecisionTreeClassifier(max_depth=20).fit(X=X, y=y)

# Test model
y_pred = dt.predict(X=X)
# evaluate model
scores = cross_val_score(dt, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# report performance
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
decisiontree=mean(scores)
# Out:
# Accuracy: 0.920 (0.004)

# %% [markdown]
# ### 3. Bagging Classifier Method

# %%
from sklearn.ensemble import BaggingClassifier

# Construct model
dt = DecisionTreeClassifier(max_depth=20)
bag = BaggingClassifier(dt, n_estimators=200, max_samples=0.9, random_state=42)


bagging=bag.fit(X=X, y=y)


# evaluate model
scores = cross_val_score(bagging, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# report performance
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
baggingc=mean(scores)
# Out:
# Accuracy: 0.937 (0.001)

# %% [markdown]
# ### 4. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Construct model
rf = RandomForestClassifier(n_estimators=200, max_samples=0.9, random_state=42)


randomf= rf.fit(X=X, y=y)


y_pred = randomf.predict(X=X)
# evaluate model
scores = cross_val_score(randomf, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# report performance
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
randomforest=mean(scores)
# Out:
# Accuracy: 0.936 (0.002)

# %% [markdown]
# ### 5. AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

adc = AdaBoostClassifier(n_estimators=10)
ada=adc.fit(X=X, y=y)

scores = cross_val_score(ada, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
adaboost=mean(scores)
# Out:
# Accuracy: 0.924 (0.004)

# %% [markdown]
# ### 6. Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=0.03)
gbc=gbc.fit(X=X, y=y)
# evaluate model
scores = cross_val_score(gbc, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# report performance
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
Gradient=mean(scores)
# Out:
# Accuracy: 0.936 (0.003)

# %% [markdown]
# ### 7. Stochastic Gradient Boost

# %%
sgbt = GradientBoostingClassifier(subsample=0.9, max_features=.2, n_estimators=30)
sgbt= sgbt.fit(X=X, y=y)
# evaluate model
scores = cross_val_score(sgbt, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# report performance
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
StochasticGradient=mean(scores)
# Out:
# Accuracy: 0.932 (0.002)

# %% [markdown]
# ### 8. XG Boost

# %%
import xgboost as xgb 
xg_cl = xgb.XGBClassifier(use_label_encoder=False, eval_metric="logloss")

xg= xg_cl.fit(X=X, y=y)
# evaluate model
scores = cross_val_score(xg, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# report performance
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
xgboost=mean(scores)
# Out:
# Accuracy: 0.937 (0.002)

# %% [markdown]
# # Model Comparison Part

# %%
print(StochasticGradient,xgboost,Gradient,adaboost,randomforest,logistic,baggingc,decisiontree)
max(StochasticGradient,xgboost,Gradient,adaboost,randomforest,logistic,baggingc,decisiontree)
# Out:
# 0.9317499999999999 0.9369250000000001 0.9360250000000001 0.924075 0.9358250000000001 0.9325499999999998 0.93685 0.919575
# 0.9369250000000001

# %%
Dict = {"Stochastic Gradient": round(StochasticGradient,4), "Xgboost": round(xgboost,4),
        "Gradient Boosting" : round(Gradient,4),
        "Adaboost":round(adaboost,4),"Random Forest":round(randomforest,4),"Logistic":round(logistic,4),
        "Bagging Classifier":round(baggingc,4),
        "Decision Tree":round(decisiontree,4)}
print(Dict)

data_ = list(Dict.items())
performance = np.array(data_)

print(performance)

#We can see that the xgboost has the highest accuracy level
# Out:
# {'Stochastic Gradient': 0.9317, 'Xgboost': 0.9369, 'Gradient Boosting': 0.936, 'Adaboost': 0.9241, 'Random Forest': 0.9358, 'Logistic': 0.9325, 'Bagging Classifier': 0.9368, 'Decision Tree': 0.9196}
# [['Stochastic Gradient' '0.9317']
#  ['Xgboost' '0.9369']
#  ['Gradient Boosting' '0.936']
#  ['Adaboost' '0.9241']
#  ['Random Forest' '0.9358']
#  ['Logistic' '0.9325']
#  ['Bagging Classifier' '0.9368']
#  ['Decision Tree' '0.9196']]

# %% [markdown]
# # CONCLUSIONS
#
# ### Data was examined the whether there is null or na value, checking structure.
# ### It was created a summary table and checked distribution of the variables.
# ### Categoric and binary variables were arranged as dummy variables.
# ### After arranging the variables Logistic Regression, Decision Tree, Bagging Classifier, Random Forrest,
# ### AdaBoost Classifier, Gradient Boosting Classifier, Stochastic Gradient Boost and Xgboost machine learning algorithms were conducted.
# ### After fitting ML models were calculated accuracy levels by evaluating with 5-fold cross validation.
# ### At end of the model performance comparison, it was concluded that XgBoost is the best model to predict situation of customer will subscribe (yes/no) to a term deposit (variable y)
